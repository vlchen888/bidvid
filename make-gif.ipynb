# %%
import imageio
import glob

images = []
for filename in sorted(list(glob.glob("out/*.png"))):
    print(filename)
    images.append(imageio.imread(filename))
imageio.mimsave('gifs/new-bad-nigahiga.gif', images)
# Out:
# out/000.png
# out/005.png
# out/010.png
# out/015.png
# out/020.png
# out/025.png
# out/030.png
# out/035.png
# out/040.png
# out/045.png
# out/050.png
# out/055.png
# out/060.png
# out/065.png
# out/070.png
# out/075.png
# out/080.png
# out/085.png
# out/090.png
# out/095.png
# out/100.png
# out/105.png
# out/110.png
# out/115.png
# out/120.png
# out/125.png
# out/130.png
# out/135.png
# out/140.png
# out/145.png
# out/150.png
# out/155.png
# out/160.png
# out/165.png
# out/170.png
# out/175.png
# out/180.png
# out/185.png
# out/190.png
# out/195.png
# out/200.png
# out/205.png
# out/210.png
# out/215.png
# out/220.png
# out/225.png
# out/230.png
# out/235.png
# out/240.png
# out/245.png
# out/250.png
# out/255.png
# out/260.png
# out/265.png
# out/270.png
# out/275.png
# out/280.png
# out/285.png
# out/290.png
# out/295.png
# out/300.png
# out/305.png
# out/310.png
# out/315.png
# out/320.png
# out/325.png
# out/330.png
# out/335.png
# out/340.png
# out/345.png
# out/350.png
# ...
